# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
train_df=pd.read_csv("train.csv")
test_df=pd.read_csv("test.csv")

# %%
train_df
# Out:
#      state  account_length      area_code international_plan voice_mail_plan  \
# 0       OH             107  area_code_415                 no             yes
# 1       NJ             137  area_code_415                 no              no
# 2       OH              84  area_code_408                yes              no
# 3       OK              75  area_code_415                yes              no
# 4       MA             121  area_code_510                 no             yes
# ...    ...             ...            ...                ...             ...
# 4245    MT              83  area_code_415                 no              no
# 4246    WV              73  area_code_408                 no              no
# 4247    NC              75  area_code_408                 no              no
# 4248    HI              50  area_code_408                 no             yes
# 4249    VT              86  area_code_415                 no             yes
#
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4250 entries, 0 to 4249
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   state                          4250 non-null   object
#  1   account_length                 4250 non-null   int64
#  2   area_code                      4250 non-null   object
#  3   international_plan             4250 non-null   object
#  4   voice_mail_plan                4250 non-null   object
#  5   number_vmail_messages          4250 non-null   int64
#  6   total_day_minutes              4250 non-null   float64
#  7   total_day_calls                4250 non-null   int64
#  8   total_day_charge               4250 non-null   float64
#  9   total_eve_minutes              4250 non-null   float64
#  10  total_eve_calls                4250 non-null   int64
#  11  total_eve_charge               4250 non-null   float64
# ...

# %%
train_df.describe()
# Out:
#        account_length  number_vmail_messages  total_day_minutes  \
# count     4250.000000            4250.000000        4250.000000
# mean       100.236235               7.631765         180.259600
# std         39.698401              13.439882          54.012373
# min          1.000000               0.000000           0.000000
# 25%         73.000000               0.000000         143.325000
# 50%        100.000000               0.000000         180.450000
# 75%        127.000000              16.000000         216.200000
# max        243.000000              52.000000         351.500000
#
#        total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  \
# count      4250.000000       4250.000000        4250.000000      4250.000000
# mean         99.907294         30.644682         200.173906       100.176471
# std          19.850817          9.182096          50.249518        19.908591
# min           0.000000          0.000000           0.000000         0.000000
# ...

# %%
train_df.duplicated().sum()
# Out:
# 0

# %%
train_df.shape
# Out:
# (4250, 20)

# %%
(train_df.isna().sum()/train_df.shape[0])*100
# Out:
# state                            0.0
# account_length                   0.0
# area_code                        0.0
# international_plan               0.0
# voice_mail_plan                  0.0
# number_vmail_messages            0.0
# total_day_minutes                0.0
# total_day_calls                  0.0
# total_day_charge                 0.0
# total_eve_minutes                0.0
# total_eve_calls                  0.0
# total_eve_charge                 0.0
# total_night_minutes              0.0
# total_night_calls                0.0
# total_night_charge               0.0
# total_intl_minutes               0.0
# total_intl_calls                 0.0
# total_intl_charge                0.0
# number_customer_service_calls    0.0
# churn                            0.0
# dtype: float64

# %%
for i in train_df.select_dtypes(include=["int","float"]).columns:
    sns.boxplot(y=train_df[i])
    sns.set_palette("Set3")
    plt.title(f"Distribution of {i}", fontsize=24, color="red")
    plt.xticks(rotation=30, color ="red")
    plt.yticks(rotation=30, color ="red")
    plt.show()

# %%
sns.boxplot(x=train_df["churn"], y=train_df["total_day_charge"])
plt.grid(axis="y")
sns.set_palette("Set3")
plt.title(f"Distribution of total daily charge by churn", fontsize=24, color="red")
plt.xticks(rotation=30, color ="red")
plt.yticks(rotation=30, color ="red")
plt.show()

# %%
sns.boxplot(x=train_df["churn"], y=train_df["total_day_calls"])
plt.grid(axis="y")
sns.set_palette("Set3")
plt.title(f"Distribution of total daily calls by churn", fontsize=24, color="red")
plt.xticks(rotation=30, color ="red")
plt.yticks(rotation=30, color ="red")
plt.show()

# %%
state_count=train_df['state'].value_counts().head(10)

# %%
sns.set_palette("Greys")
fig, ax=plt.subplots(figsize=(10,6))
state_count.plot(kind='bar')
plt.grid(axis="y")
plt.title(f"Top 10 States", fontsize=24, color="red")
plt.xticks(rotation=30, color ="red")
plt.yticks(rotation=30, color ="red")
plt.show()

# %%
def cat_cat(col):
    sns.set_palette("Greys")
    fig, ax=plt.subplots(figsize=(10,6))
    cat_cat=pd.crosstab(
        index=train_df["churn"],
        columns= train_df[col],
        values=train_df["churn"],
        aggfunc="count")
    cat_cat.plot(kind="bar", ax=ax)
    plt.grid(axis="y")
    plt.title(f"count of {col} by churn", fontsize=24, color="red")
    plt.xticks(rotation=30, color ="red")
    plt.yticks(rotation=30, color ="red")
    plt.show()

# %%
cat_cat("total_intl_calls")

# %%
cat_cat("state")

# %%
sns.scatterplot(data=train_df, x="churn", y="state", hue="total_day_calls")
# Out:
# <AxesSubplot:xlabel='churn', ylabel='state'>
